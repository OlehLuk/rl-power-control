# %%
from visualize import report_const_experiment, report_experiment, report_experiment_summary, plot_sys_behaviour, \
plot_agent_behaviour, plot_two_perf_dist, plot_agent_sys_exploit_behaviour, mse_vs_ref, plot_perf_dist, perf_viol_split
# %matplotlib inline

# %%
baseline_name = "ps_stoch/constant_action_variation_20-10-2019_21-13"
report_const_experiment(baseline_name, fig_size=(12, 35))

# %%
experiments_folder = "ps_stoch/5s_cases/best_params_300ep_5s/"
experiment_name = "Stoch.PS, window Q-learning:"
case = "time_step=5"
case_name = ""
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.16317777 0.16408772 0.16303053 0.1631556  0.16321452] s
# Mean time per simulation step: 0.163 s, std: 0.0004 s
# Total execution time: 9799.994 s for 60000 steps -> 0.163 s per step
#
# Median performance (MSE) in exploitation mode 0.0146
#
# Average MSE in exploitation mode 0.0156 +- 0.0031
# Average exploitation performance of each agent:
# [0.015116 0.016952 0.015246 0.014408 0.01603 ]

# %% [markdown]
# ## New baselines

# %%
name = "ps_stoch/new_compete/baseline12_50ep_1s"
report_const_experiment(name, fig_size=(12, 35))

# %%
name = "ps_stoch/new_compete/baseline12_50ep_5s"
report_const_experiment(name, fig_size=(12, 35))

# %%
labels = ["300ep"]
bas_folders = [baseline_name +"/k=7"
               ]
contr_folders = ["ps_stoch/5s_cases/best_params_300ep_5s/time_step=5"
                 ]
df_bas_mses, df_contr_mses = mse_vs_ref(labels, bas_folders, contr_folders, fig_size=(10, 6), x_label="Hop.window size")

# %% [markdown]
# ## Skipping transition

# %%
skip175baseline = "ps_stoch/new_compete/baseline12_skip175_50ep_1s"
report_const_experiment(skip175baseline, fig_size=(12, 35))

# %%
skip175baseline = "ps_stoch/new_compete/baseline12_skip175_50ep_5s"
report_const_experiment(skip175baseline, fig_size=(12, 35))

# %%
experiments_folder = "ps_stoch/5s_cases/best_params_skip_175_5s/"
experiment_name = "Stoch.PS, window Q-learning:"
case = "time_step=5"
case_name = ""
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.2114779  0.210844   0.21104077 0.21079777 0.21279708] s
# Mean time per simulation step: 0.211 s, std: 0.0007 s
# Total execution time: 4227.830 s for 20000 steps -> 0.211 s per step
#
# Median performance (MSE) in exploitation mode 0.0084
#
# Average MSE in exploitation mode 0.0087 +- 0.0039
# Average exploitation performance of each agent:
# [0.008568 0.008962 0.00883  0.007874 0.009364]

# %%
labels = ["5s controller"]
bas_folders = [skip175baseline +"/k=5"
               ]
contr_folders = ["ps_stoch/5s_cases/best_params_skip_175_5s/time_step=5"
                 ]
df_bas_mses, df_contr_mses = mse_vs_ref(labels, bas_folders, contr_folders, fig_size=(10, 6), x_label="")
