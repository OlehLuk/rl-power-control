# %%
from visualize import report_const_experiment, report_experiment, report_experiment_summary, plot_sys_behaviour, \
plot_agent_behaviour, plot_two_perf_dist, plot_agent_sys_exploit_behaviour, mse_vs_ref
# %matplotlib inline

# %% [markdown]
# # Stochastic case, constant `p_reff` - power reference

# %%
case_folder = "ps_stoch/"

# %% [markdown]
# ## Alternative hypothesis: p_reff=1.2 is a specific case where constant control outperforms RL controller, let's consider p_reff=1.25

# %% [markdown]
# ## Baseline exeperiment - constant action applied instead of controller-chosen action

# %% [markdown]
# ## time_step=1s

# %%
name = case_folder + "baseline_other_ref_27-10-2019_07-28"
report_const_experiment(name, fig_size=(12, 35))

# %% [markdown]
# ## Q-learning
# ## Q-learning hyperparameters chosen on the p_reff=const case

# %%
experiments_folder = case_folder + "best_params_other_ref_27-10-2019_08-50/"
experiment_name = "Stoch.PS, Q-learning:"

# %%
case = "time_step=1"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.23547622 0.23770299 0.23818488 0.24909513 0.23076543] s
# Mean time per simulation step: 0.238 s, std: 0.0060 s
# Total execution time: 23824.493 s for 100000 steps -> 0.238 s per step
#
# Average MSE in exploitation mode 0.0118 +- 0.0013
# Average exploitation performance of each agent:
# [0.01176  0.011126 0.01266  0.011358 0.011864]

# %%
plot_agent_behaviour(experiments_folder + "/time_step=1")

# %%
plot_sys_behaviour(experiments_folder + "/time_step=1")

# %%
plot_agent_sys_exploit_behaviour(experiments_folder + "/time_step=1")

# %% [markdown]
# ## Performance distributions:

# %%
controller = case_folder + "best_params_other_ref_27-10-2019_08-50/time_step=1"
baseline = case_folder + "baseline_other_ref_27-10-2019_07-28/k=7"
plot_two_perf_dist(baseline, controller);

# %% [markdown]
# -------------------------------------------------------
# ## Alternative hypothesis: p_reff=1.2 is a specific case where constant control outperforms RL controller, let's consider p_reff=1.15

# %%
name = case_folder + "baseline_lower_ref_28-10-2019_21-17"
report_const_experiment(name, fig_size=(12, 35))

# %%
experiments_folder = case_folder + "best_params_lower_ref_28-10-2019_22-30/"
experiment_name = "Stoch.PS, Q-learning:"
case = "time_step=1"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.20645502 0.20632182 0.2062443  0.20632037 0.20661105] s
# Mean time per simulation step: 0.206 s, std: 0.0001 s
# Total execution time: 20639.051 s for 100000 steps -> 0.206 s per step
#
# Average MSE in exploitation mode 0.0203 +- 0.0048
# Average exploitation performance of each agent:
# [0.020338 0.019816 0.01956  0.020682 0.02096 ]

# %%
plot_agent_sys_exploit_behaviour(experiments_folder + "/time_step=1")

# %%
controller = case_folder + "best_params_lower_ref_28-10-2019_22-30/time_step=1"
baseline = case_folder + "baseline_lower_ref_28-10-2019_21-17/k=7"
plot_two_perf_dist(baseline, controller);

# %% [markdown]
# ---------------------------------------------
# # Alternative hypothesis: for p_reff=1.2 case constant control outperforms RL controller, because of transition process in the beginning (150 seconds)

# %% [markdown]
# ## Baseline exeperiment - constant action applied instead of controller-chosen action

# %%
name = case_folder + "baseline_skip_transition_27-10-2019_18-18"
report_const_experiment(name, fig_size=(12, 35))

# %% [markdown]
# ## Q-learning
# ## Q-learning hyperparameters chosen on the p_reff=const case

# %%
experiments_folder = case_folder + "best_params_skip_transition_27-10-2019_20-15/"
experiment_name = "Stoch.PS, Q-learning:"

# %%
case = "time_step=1"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.25821926 0.25353674 0.21868929 0.21272774 0.21103645] s
# Mean time per simulation step: 0.231 s, std: 0.0207 s
# Total execution time: 23084.190 s for 100000 steps -> 0.231 s per step
#
# Average MSE in exploitation mode 0.0086 +- 0.0015
# Average exploitation performance of each agent:
# [0.008504 0.00902  0.008814 0.008806 0.007892]

# %%
plot_agent_sys_exploit_behaviour(experiments_folder + "/time_step=1")

# %%
controller = case_folder + "best_params_skip_transition_27-10-2019_20-15/time_step=1"
baseline = case_folder + "baseline_skip_transition_27-10-2019_18-18/k=7"
plot_two_perf_dist(baseline, controller);

# %%
plot_agent_sys_exploit_behaviour(experiments_folder + "/time_step=1")

# %% [markdown]
# ---------------------------------------------
# # Alternative hypothesis: for p_reff=1.2 case constant control outperforms RL controller, because of transition process in the beginning, skip 175 seconds, learning_rate=0.3, actions [0.1, 1, 7]
# ## Baseline exeperiment - constant action applied instead of controller-chosen action

# %%
name = case_folder + "baseline_skip_transition_28-10-2019_12-59"
report_const_experiment(name, fig_size=(12, 35))

# %%
experiments_folder = case_folder + "best_params_skip_transition_28-10-2019_14-16/"
experiment_name = "Stoch.PS, Q-learning:"

# %%
case = "time_step=1"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.22162342 0.22146241 0.22027054 0.21908184 0.22130515] s
# Mean time per simulation step: 0.221 s, std: 0.0010 s
# Total execution time: 22074.867 s for 100000 steps -> 0.221 s per step
#
# Average MSE in exploitation mode 0.0086 +- 0.0021
# Average exploitation performance of each agent:
# [0.00915  0.00781  0.00837  0.00928  0.008356]

# %%
plot_agent_sys_exploit_behaviour(experiments_folder + "/time_step=1")

# %%
controller = case_folder + "best_params_skip_transition_28-10-2019_14-16/time_step=1"
baseline = case_folder + "baseline_skip_transition_28-10-2019_12-59/k=5"
plot_two_perf_dist(baseline, controller);

# %% [markdown]
# ---------------------------------------------
# # Alternative hypothesis: for p_reff=1.25 case constant control outperforms RL controller, because of transition process in the beginning, skip 150 seconds
# ## Baseline exeperiment - constant action applied instead of controller-chosen action

# %%
name = case_folder + "baseline_skip_transition_other_ref_29-10-2019_04-14"
report_const_experiment(name, fig_size=(12, 35))

# %%
experiments_folder = case_folder + "best_params_skip_transition_other_ref_29-10-2019_05-29/"
experiment_name = "Stoch.PS, Q-learning:"
case = "time_step=1"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.20978334 0.20987442 0.21006346 0.21067204 0.21453195] s
# Mean time per simulation step: 0.211 s, std: 0.0018 s
# Total execution time: 21098.504 s for 100000 steps -> 0.211 s per step
#
# Average MSE in exploitation mode 0.0050 +- 0.0033
# Average exploitation performance of each agent:
# [0.004638 0.004908 0.005554 0.00471  0.00511 ]

# %%
plot_agent_sys_exploit_behaviour(experiments_folder + "/time_step=1")

# %%
controller = case_folder + "best_params_skip_transition_other_ref_29-10-2019_05-29/time_step=1"
baseline = case_folder + "baseline_skip_transition_other_ref_29-10-2019_04-14/k=2"
plot_two_perf_dist(baseline, controller);

# %% [markdown]
# ## MSE distribution vs const p_reff

# %%
labels = ["1.15", "1.2", "1.25"]
bas_folders = ["ps_stoch/baseline_lower_ref_28-10-2019_21-17/k=7",
           "ps_stoch/constant_action_variation_20-10-2019_19-55/k=7",
           "ps_stoch/baseline_other_ref_27-10-2019_07-28/k=7"]
contr_folders = ["ps_stoch/best_params_lower_ref_28-10-2019_22-30/time_step=1",
           "ps_stoch/best_parameters_combination_19-09-2019_13-33/time_step=1",
           "ps_stoch/best_params_other_ref_27-10-2019_08-50/time_step=1"]

# %%
df_bas_mses, df_contr_mses = mse_vs_ref(labels, bas_folders, contr_folders, fig_size=(12, 9))
