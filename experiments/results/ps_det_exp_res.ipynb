# %%
from visualize import report_const_experiment, report_experiment, report_experiment_summary, plot_sys_behaviour, \
plot_agent_behaviour
# %matplotlib inline

# %% [markdown]
# # Deterministic case, constant `p_reff` - power reference

# %%
case_folder = "ps_det/"

# %% [markdown]
# ## Baseline exeperiment - constant action applied instead of controller-chosen action

# %% [markdown]
# ## time_step=1s

# %%
name = case_folder + "constant_action_variation_20-10-2019_18-46"
report_const_experiment(name, fig_size=(12, 35))

# %% [markdown]
# ## time_step=5s

# %%
name = case_folder + "constant_action_variation_20-10-2019_19-53"
report_const_experiment(name, fig_size=(12, 35))

# %% [markdown]
# # Control with Q-learning
# ## Experiments to find optimal hyperparameters

# %% [markdown]
# ## 1. Different action spaces

# %%
experiments_folder = case_folder + "action_space(k_s)_variation_19-10-2019_22-08/"
experiment_name = "Det.PS, Q-learning, Action space variation:"

# %% [markdown]
# ### k_s=[1,2,3]

# %%
case = "k_s=[1, 2, 3]"
df_ks_1_avgsm_mses, perf_ks1, sig_ks1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case), plot_perf_sigma=1, stochastic=False)
# Out:
# Last episode performance: 0.09
# Time per simulation step in each experiment: [0.1446859  0.14418062 0.1445034  0.14399869 0.14399466] s
# Mean time per simulation step: 0.144 s, std: 0.0003 s
# Total execution time: 14427.265 s for 100000 steps -> 0.144 s per step
#
# Average MSE in exploitation mode 0.0903 +- 0.0013
# Average exploitation performance of each agent:
# [0.0894 0.0917 0.0917 0.0894 0.0894]

# %% [markdown]
# ## k=[0.5,1,2,3,4]

# %%
case = "k_s=[0.5, 1, 2, 3, 4]"
df_ks_2_avgsm_mses, perf_ks2, sig_ks2 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case), stochastic=False)
# Out:
# Last episode performance: 0.09
# Time per simulation step in each experiment: [0.14334337 0.14350567 0.1433012  0.14399281 0.14394435] s
# Mean time per simulation step: 0.144 s, std: 0.0003 s
# Total execution time: 14361.748 s for 100000 steps -> 0.144 s per step
#
# Average MSE in exploitation mode 0.0927 +- 0.0080
# Average exploitation performance of each agent:
# [0.089  0.106  0.0855 0.0936 0.0895]

# %% [markdown]
# ## k_s = [0.1, 0.5, 1, 2, 7]

# %%
case = "k_s=[0.1, 0.5, 1, 2, 7]"
df_ks_3_avgsm_mses, perf_ks3, sig_ks3 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case), stochastic=False)
# Out:
# Last episode performance: 0.09
# Time per simulation step in each experiment: [0.1438821  0.14398162 0.14410892 0.14336963 0.14973496] s
# Mean time per simulation step: 0.145 s, std: 0.0024 s
# Total execution time: 14501.544 s for 100000 steps -> 0.145 s per step
#
# Average MSE in exploitation mode 0.0898 +- 0.0006
# Average exploitation performance of each agent:
# [0.0892 0.0902 0.0898 0.0892 0.0904]

# %% [markdown]
# ## Summary

# %%
labels = ["[1,2,3]", "[0.5,1,2,3,4]", "[0.1,0.5,1,2,7]"]
mses = [df_ks_1_avgsm_mses, df_ks_2_avgsm_mses, df_ks_3_avgsm_mses]
perfs = [perf_ks1, perf_ks2, perf_ks3]
sigs = [sig_ks1, sig_ks2, sig_ks3]
report_experiment_summary("Different action spaces", mses, perfs, sigs, labels, 0)

# %% [markdown]
# ## 2. Exploration rate variation

# %%
experiments_folder = case_folder + "exploration(rate_and_discount)_variation_07-09-2019_10-03/"
experiment_name = "Det.PS, Q-learning, Exploration parameters variation:"

# %% [markdown]
# ### exploration_rate=0.2, exploration_rate_decay=1

# %%
case = "expl_rate=0.2_decay=1"
df_expl1_avgsm_mses, perf_expl1, sig_expl1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case), stochastic=False)
# Out:
# Last episode performance: 0.10
# Time per simulation step in each experiment: [0.16154153 0.16733918 0.15775669 0.16280798 0.15845064] s
# Mean time per simulation step: 0.162 s, std: 0.0034 s
# Total execution time: 16157.920 s for 100000 steps -> 0.162 s per step
#
# Average MSE in exploitation mode 0.0950 +- 0.0089
# Average exploitation performance of each agent:
# [0.096863 0.095493 0.0863   0.1084   0.08792 ]

# %% [markdown]
# ### exploration_rate=1, exploration_rate_decay=0.99

# %%
case = "expl_rate=1_decay=0.99"
df_expl2_avgsm_mses, perf_expl2, sig_expl2 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case), stochastic=False)
# Out:
# Last episode performance: 0.09
# Time per simulation step in each experiment: [0.21318191 0.15241689 0.15246749 0.1566215  0.15716021] s
# Mean time per simulation step: 0.166 s, std: 0.0235 s
# Total execution time: 16636.960 s for 100000 steps -> 0.166 s per step
#
# Average MSE in exploitation mode 0.0901 +- 0.0010
# Average exploitation performance of each agent:
# [0.0893 0.0902 0.0904 0.0891 0.0915]

# %% [markdown]
# ## Summary

# %%
labels = ["0.2, 1", "1, 0.99", "0.5, 0.9"]
mses = [df_expl1_avgsm_mses, df_expl2_avgsm_mses, df_ks_3_avgsm_mses]
perfs = [perf_expl1, perf_expl2, perf_ks3]
sigs = [sig_expl1, sig_expl2, sig_ks3]
report_experiment_summary("Different exploration parameters", mses, perfs, sigs, labels, 0)

# %% [markdown]
# ## 3. Time step variation

# %%
experiments_folder = case_folder + "time_step_variation_08-09-2019_14-17/"
experiment_name = "Det.PS, Q-learning, Time step variation:"

# %% [markdown]
# ### time_step=2

# %%
case = "time_step=2"
df_ts1_avgsm_mses, perf_ts1, sig_ts1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case), stochastic=False)
# Out:
# Last episode performance: 0.10
# Time per simulation step in each experiment: [0.15495269 0.17795312 0.18481918 0.17345553 0.17866357] s
# Mean time per simulation step: 0.174 s, std: 0.0102 s
# Total execution time: 8698.441 s for 50000 steps -> 0.174 s per step
#
# Average MSE in exploitation mode 0.0941 +- 0.0104
# Average exploitation performance of each agent:
# [0.0826   0.107    0.097564 0.0859   0.097634]

# %% [markdown]
# ### time_step=5

# %%
case = "time_step=5"
df_ts2_avgsm_mses, perf_ts2, sig_ts2 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case), stochastic=False)
# Out:
# Last episode performance: 0.09
# Time per simulation step in each experiment: [0.18505488 0.17132202 0.17757898 0.1882344  0.1755814 ] s
# Mean time per simulation step: 0.180 s, std: 0.0062 s
# Total execution time: 3591.087 s for 20000 steps -> 0.180 s per step
#
# Average MSE in exploitation mode 0.0820 +- 0.0061
# Average exploitation performance of each agent:
# [0.0802 0.0895 0.0868 0.0744 0.0789]

# %% [markdown]
# ### Summary

# %%
labels = ["2", "5", "1"]
mses = [df_ts1_avgsm_mses, df_ts2_avgsm_mses, df_ks_3_avgsm_mses]
perfs = [perf_ts1, perf_ts2, perf_ks3]
sigs = [sig_ts1, sig_ts2, sig_ks3]
report_experiment_summary("Different control change time step", mses, perfs, sigs, labels, 0)

# %% [markdown]
# ## 4. Learning rate variation

# %%
experiments_folder = case_folder + "learning_rate_variation_09-09-2019_22-15/"
experiment_name = "Det.PS, Q-learning, Learning rate variation:"

# %% [markdown]
# ### learning_rate=0.2

# %%
case = "learning_rate=0.2"
df_lr1_avgsm_mses, perf_lr1, sig_lr1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case), stochastic=False)
# Out:
# Last episode performance: 0.09
# Time per simulation step in each experiment: [0.15305079 0.15060034 0.15261128 0.15068968 0.15109809] s
# Mean time per simulation step: 0.152 s, std: 0.0010 s
# Total execution time: 15161.003 s for 100000 steps -> 0.152 s per step
#
# Average MSE in exploitation mode 0.0935 +- 0.0071
# Average exploitation performance of each agent:
# [0.0886 0.09   0.0972 0.0875 0.1042]

# %%
case = "learning_rate=0.8"
df_lr2_avgsm_mses, perf_lr2, sig_lr2 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case), stochastic=False)
# Out:
# Last episode performance: 0.09
# Time per simulation step in each experiment: [0.15036471 0.15081196 0.15109915 0.1498702  0.15037576] s
# Mean time per simulation step: 0.151 s, std: 0.0004 s
# Total execution time: 15050.435 s for 100000 steps -> 0.151 s per step
#
# Average MSE in exploitation mode 0.0909 +- 0.0058
# Average exploitation performance of each agent:
# [0.0872 0.0938 0.0849 0.0995 0.089 ]

# %%
labels = ["0.2", "0.8", "0.5"]
mses = [df_lr1_avgsm_mses, df_lr2_avgsm_mses, df_ks_3_avgsm_mses]
perfs = [perf_lr1, perf_lr2, perf_ks3]
sigs = [sig_lr1, sig_lr2, sig_ks3]
report_experiment_summary("Different learning rate", mses, perfs, sigs, labels, 0)

# %% [markdown]
# ## 5. Discount factor variation

# %%
experiments_folder = case_folder + "discount_factor_variation_10-09-2019_11-25/"
experiment_name = "Det.PS, Q-learning, Discount factor variation:"

# %% [markdown]
# ### discount_factor=0.2

# %%
case = "discount_factor=0.2"
df_df1_avgsm_mses, perf_df1, sig_df1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case), stochastic=False)
# Out:
# Last episode performance: 0.09
# Time per simulation step in each experiment: [0.15825019 0.17518819 0.17233141 0.17857158 0.1614713 ] s
# Mean time per simulation step: 0.169 s, std: 0.0079 s
# Total execution time: 16916.253 s for 100000 steps -> 0.169 s per step
#
# Average MSE in exploitation mode 0.0894 +- 0.0006
# Average exploitation performance of each agent:
# [0.0904 0.0893 0.0889 0.0891 0.0893]

# %%
case = "discount_factor=0.9"
df_df2_avgsm_mses, perf_df2, sig_df2 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case), stochastic=False)
# Out:
# Last episode performance: 0.10
# Time per simulation step in each experiment: [0.18400968 0.19353286 0.15477157 0.15527325 0.15511412] s
# Mean time per simulation step: 0.169 s, std: 0.0168 s
# Total execution time: 16854.030 s for 100000 steps -> 0.169 s per step
#
# Average MSE in exploitation mode 0.0905 +- 0.0043
# Average exploitation performance of each agent:
# [0.0956 0.0838 0.0904 0.091  0.0919]

# %%
labels = ["0.2", "0.9", "0.6"]
mses = [df_df1_avgsm_mses, df_df2_avgsm_mses, df_ks_3_avgsm_mses]
perfs = [perf_df1, perf_df2, perf_ks3]
sigs = [sig_df1, sig_df2, sig_ks3]
report_experiment_summary("Different discount factor", mses, perfs, sigs, labels, 0)

# %% [markdown]
# ## 6. Reward variation

# %%
experiments_folder = case_folder + "reward_variation_11-09-2019_23-13/"
experiment_name = "Det.PS, Q-learning, Reward method variation:"

# %% [markdown]
# ## Reward - absolute difference between actual and reference power, scaled up by 100

# %%
case = "reward--AEx100"
df_rw1_avgsm_mses, perf_rw1, sig_rw1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case), stochastic=False)
# Out:
# Last episode performance: 0.09
# Time per simulation step in each experiment: [0.15317584 0.15360354 0.15384238 0.15406719 0.1538522 ] s
# Mean time per simulation step: 0.154 s, std: 0.0003 s
# Total execution time: 15370.823 s for 100000 steps -> 0.154 s per step
#
# Average MSE in exploitation mode 0.0912 +- 0.0046
# Average exploitation performance of each agent:
# [0.0992 0.0898 0.0872 0.0905 0.0892]

# %% [markdown]
# ## Reward - squared difference between actual and reference power, scaled up by 100

# %%
case = "reward--SEx100"
df_rw2_avgsm_mses, perf_rw2, sig_rw2 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case), stochastic=False)
# Out:
# Last episode performance: 0.09
# Time per simulation step in each experiment: [0.16110036 0.15497379 0.15551451 0.15420037 0.15579999] s
# Mean time per simulation step: 0.156 s, std: 0.0025 s
# Total execution time: 15631.780 s for 100000 steps -> 0.156 s per step
#
# Average MSE in exploitation mode 0.0891 +- 0.0013
# Average exploitation performance of each agent:
# [0.0893 0.0903 0.0892 0.087  0.0897]

# %% [markdown]
# ## Summary

# %%
labels = ["-AEx100", "-SEx100", "-SEx1000"]
mses = [df_rw1_avgsm_mses, df_rw2_avgsm_mses, df_ks_3_avgsm_mses]
perfs = [perf_rw1, perf_rw2, perf_ks3]
sigs = [sig_rw1, sig_rw2, sig_ks3]
report_experiment_summary("Different reward", mses, perfs, sigs, labels, 0)

# %% [markdown]
# # 7. Closer look at the best configurations:

# %% [markdown]
# ## Parameters:
# * n_experiments=5,
# * n_episodes=100,
# * visualize=False,
# * max_n_steps=40, - 200//5 - faster experiments/longer horizon
# * time_step=5,
# * p_reff=1.2,
# * rand_qtab=False,
# * learning_rate=0.5
# * discount_factor=0.6
# * k_s=[0.1, 0.5, 1, 2, 7],
# * exploration_rate=0.5,
# * exploration_decay_rate=0.9,
# * log_level=logging.INFO

# %%
plot_sys_behaviour("./ps_det/time_step_variation_08-09-2019_14-17/time_step=5/", old=True)

# %%
plot_agent_behaviour("./ps_det/time_step_variation_08-09-2019_14-17/time_step=5")

# %%
plot_sys_behaviour("./ps_det/action_space(k_s)_variation_19-10-2019_22-08/k_s=[0.1, 0.5, 1, 2, 7]")

# %%
plot_sys_behaviour("./ps_det/discount_factor_variation_10-09-2019_11-25/discount_factor=0.2", old=True)

# %% [markdown]
# # Best parameters set
# ## for time step equal 1s and 5s. Trained twice longer - 200 episodes

# %%
experiments_folder = case_folder + "best_parameters_combination_13-09-2019_12-55/"
experiment_name = "Det.PS, Q-learning, Best options"

# %% [markdown]
# ## time_step=1

# %%
case = "time_step=1"
df_best1_avgsm_mses, perf_best1, sig_best1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case), stochastic=False)
# Out:
# Last episode performance: 0.09
# Time per simulation step in each experiment: [0.16400605 0.15530691 0.16305632 0.16195518 0.15528828] s
# Mean time per simulation step: 0.160 s, std: 0.0038 s
# Total execution time: 31984.510 s for 200000 steps -> 0.160 s per step
#
# Average MSE in exploitation mode 0.0896 +- 0.0008
# Average exploitation performance of each agent:
# [0.0895 0.0888 0.091  0.0894 0.0894]

# %% [markdown]
# ## time_step=5

# %%
case = "time_step=5"
df_best2_avgsm_mses, perf_best2, sig_best2 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case), stochastic=False)
# Out:
# Last episode performance: 0.08
# Time per simulation step in each experiment: [0.16670003 0.16615992 0.16617756 0.16546621 0.16547224] s
# Mean time per simulation step: 0.166 s, std: 0.0005 s
# Total execution time: 6639.808 s for 40000 steps -> 0.166 s per step
#
# Average MSE in exploitation mode 0.0822 +- 0.0110
# Average exploitation performance of each agent:
# [0.0668 0.0921 0.0936 0.0804 0.0783]

# %% [markdown]
# ## Summary

# %%
labels = ["t=1 (200 ep.)", "t=5 (200 ep.)", "t=1 (100 ep.)", "t=5 (100 ep.)"]
mses = [df_best1_avgsm_mses, df_best2_avgsm_mses, df_ks_3_avgsm_mses, df_ts2_avgsm_mses]
perfs = [perf_best1, perf_best2, perf_ks3, perf_ts2]
sigs = [sig_best1, sig_best2, sig_ks3, sig_ts2]
report_experiment_summary("Different time step and training time", mses, perfs, sigs, labels, 0)

# %%
labels = ["t=1 (200 ep.)", "t=1 (100 ep.)"]
mses = [df_best1_avgsm_mses, df_ks_3_avgsm_mses]
perfs = [perf_best1, perf_ks3]
sigs = [sig_best1, sig_ks3]
report_experiment_summary("Different training time", mses, perfs, sigs, labels, 0)

# %% [markdown]
# ### With t=1s, we reached exploitation performance already reached at 100 episodes. Seems like the policy have converged to exploitation.
#
# ### For t=5s - is very efficient on average, but has too high variance of exploitation performance.
