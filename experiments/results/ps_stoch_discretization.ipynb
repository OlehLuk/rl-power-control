# %%
from visualize import report_const_experiment, report_experiment, report_experiment_summary, plot_sys_behaviour, \
plot_agent_behaviour, plot_two_perf_dist, plot_agent_sys_exploit_behaviour, mse_vs_ref, plot_perf_dist, perf_box_plots,\
perf_viol_split, perf_violins

# %matplotlib inline

# %%
case_folder = "ps_stoch_adv/"

# %%
baseline_name = "ps_stoch/new_compete/baseline12_50ep_1s"
report_const_experiment(baseline_name, fig_size=(12, 35))

# %% [markdown]
# ## Different intervals

# %%
experiments_folder = case_folder + "wiql/slide_win_exp_100_bins/"
experiment_name = "Stoch.PS, window Q-learning:"
case = "window_size=1"
case_name = "[0.1;1.7] 100 bins"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.20819855 0.20767403 0.20805836 0.20841476 0.20966404] s
# Mean time per simulation step: 0.208 s, std: 0.0007 s
# Total execution time: 20840.195 s for 100000 steps -> 0.208 s per step
#
# Median performance (MSE) in exploitation mode 0.0123
#
# Average MSE in exploitation mode 0.0132 +- 0.0021
# Average exploitation performance of each agent:
# [0.012954 0.013696 0.01285  0.013186 0.013278]

# %%
labels = ["10 bins [0.9;1.7]", "100 bins [0.9;1.7]", "100 bins [0.1;1.7]"]
bas_folders = [baseline_name +"/k=7",
               baseline_name +"/k=7",
               baseline_name +"/k=7",
               ]
contr_folders = ["ps_stoch_adv/wiql/slide_win_exp_10_09-17_bins/window_size=1",
                 "ps_stoch_adv/wiql/slide_win_exp_100_09-17_bins/window_size=1",
                 "ps_stoch_adv/wiql/slide_win_exp_100_bins/window_size=1"                 
                 ]
df_bas_mses, df_contr_mses = mse_vs_ref(labels, bas_folders, contr_folders, fig_size=(10, 6), 
                                        x_label="Discretization type")

# %%
perf_box_plots(labels, bas_folders[:1], contr_folders, fig_size=(9, 6), x_label="Discretization strategy");

# %%
perf_viol_split(labels, bas_folders, contr_folders, fig_size=(9, 6), x_label="Discretization strategy");

# %% [markdown]
# ## Change of the number of bins for interval [0.9;1.7]

# %%
experiments_folder = case_folder + "wiql/slide_win_exp_10_09-17_bins/"
experiment_name = "Stoch.PS, window Q-learning:"
case = "window_size=1"
case_name = "[0.9;1.7] 10 bins"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.20187463 0.20193521 0.20163681 0.20203166 0.2018509 ] s
# Mean time per simulation step: 0.202 s, std: 0.0001 s
# Total execution time: 20186.584 s for 100000 steps -> 0.202 s per step
#
# Median performance (MSE) in exploitation mode 0.0126
#
# Average MSE in exploitation mode 0.0133 +- 0.0021
# Average exploitation performance of each agent:
# [0.013626 0.012724 0.013168 0.013386 0.013438]

# %%
experiments_folder = case_folder + "discretization/slide_win_exp_25_09-17_bins/"
experiment_name = "Stoch.PS, window Q-learning:"
case = "window_size=1"
case_name = "[0.9;1.7] 25 bins"
df_avgsm_mses_4, perf_4, sig_4 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.20927255 0.23371844 0.22282754 0.21916694 0.210873  ] s
# Mean time per simulation step: 0.219 s, std: 0.0089 s
# Total execution time: 21917.169 s for 100000 steps -> 0.219 s per step
#
# Median performance (MSE) in exploitation mode 0.0121
#
# Average MSE in exploitation mode 0.0131 +- 0.0036
# Average exploitation performance of each agent:
# [0.01225  0.01365  0.013766 0.012326 0.01338 ]

# %%
experiments_folder = case_folder + "discretization/slide_win_exp_50_09-17_bins//"
experiment_name = "Stoch.PS, window Q-learning:"
case = "window_size=1"
case_name = "[0.9;1.7] 50 bins"
df_avgsm_mses_4, perf_4, sig_4 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.20908175 0.20864721 0.20840353 0.20948963 0.2082925 ] s
# Mean time per simulation step: 0.209 s, std: 0.0004 s
# Total execution time: 20878.292 s for 100000 steps -> 0.209 s per step
#
# Median performance (MSE) in exploitation mode 0.0126
#
# Average MSE in exploitation mode 0.0132 +- 0.0025
# Average exploitation performance of each agent:
# [0.012412 0.01409  0.013376 0.01293  0.013408]

# %%
experiments_folder = case_folder + "wiql/slide_win_exp_100_09-17_bins/"
experiment_name = "Stoch.PS, window Q-learning:"
case = "window_size=1"
case_name = "[0.9;1.7] 100 bins"
df_avgsm_mses_4, perf_4, sig_4 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.20610345 0.20660388 0.20641809 0.2066407  0.20635642] s
# Mean time per simulation step: 0.206 s, std: 0.0002 s
# Total execution time: 20642.451 s for 100000 steps -> 0.206 s per step
#
# Median performance (MSE) in exploitation mode 0.0127
#
# Average MSE in exploitation mode 0.0142 +- 0.0071
# Average exploitation performance of each agent:
# [0.016084 0.01404  0.013546 0.013856 0.013392]

# %%
labels = ["10 bins", "25 bins", "50 bins", "100 bins"]
bas_folders = [baseline_name +"/k=7",
               baseline_name +"/k=7",
               baseline_name +"/k=7",
               baseline_name +"/k=7",
               ]
contr_folders = ["ps_stoch_adv/wiql/slide_win_exp_10_09-17_bins/window_size=1",
                 "ps_stoch_adv/discretization/slide_win_exp_25_09-17_bins//window_size=1",
                 "ps_stoch_adv/discretization/slide_win_exp_50_09-17_bins//window_size=1",
                 "ps_stoch_adv/wiql/slide_win_exp_100_09-17_bins/window_size=1"
                 ]
df_bas_mses, df_contr_mses = mse_vs_ref(labels, bas_folders, contr_folders, fig_size=(10, 6), 
                                        x_label="N bins for [0.9;1.7] interval")

# %%
perf_viol_split(labels, bas_folders, contr_folders, fig_size=(9, 6), x_label="N bins for [0.9;1.7] interval");

# %%
plot_perf_dist(bas_folders[0], contr_folders[0:2], labels[0:2]);

# %%
plot_perf_dist(bas_folders[0], contr_folders[2:], labels[2:]);

# %% [markdown]
# # Smart discretization strategies
# ## Binning using quantiles, histigram and reference power level as an edge of the bin
# ## 1. Without skipping transition:

# %% [markdown]
# ### Binning using quantiles

# %%
experiments_folder = case_folder + "discretization/ql_baseline12_quantile_10bins/"
experiment_name = "Stoch.PS, window Q-learning:"
case = "window_size=1"
case_name = "Baseline experiment historic data, 10 quantile bins"
df_avgsm_mses_4, perf_4, sig_4 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.21123169 0.20383187 0.20420108 0.20416128 0.20537383] s
# Mean time per simulation step: 0.206 s, std: 0.0028 s
# Total execution time: 20575.995 s for 100000 steps -> 0.206 s per step
#
# Median performance (MSE) in exploitation mode 0.0128
#
# Average MSE in exploitation mode 0.0134 +- 0.0041
# Average exploitation performance of each agent:
# [0.013238 0.013986 0.012868 0.013294 0.01382 ]

# %%
experiments_folder = case_folder + "discretization/ql_ql12_32ep_quantile_10bins/"
experiment_name = "Stoch.PS, window Q-learning:"
case = "window_size=1"
case_name = "Q-learning experiment historic data, 10 quantile bins"
df_avgsm_mses_4, perf_4, sig_4 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.2221413  0.20544551 0.20485333 0.20470865 0.20566627] s
# Mean time per simulation step: 0.209 s, std: 0.0068 s
# Total execution time: 20856.301 s for 100000 steps -> 0.209 s per step
#
# Median performance (MSE) in exploitation mode 0.0126
#
# Average MSE in exploitation mode 0.0137 +- 0.0030
# Average exploitation performance of each agent:
# [0.014186 0.01277  0.013208 0.013446 0.014764]

# %% [markdown]
# ### Binning using histogram

# %%
experiments_folder = case_folder + "discretization/ql_baseline12_hist_bins/"
experiment_name = "Stoch.PS, window Q-learning:"
case = "window_size=1"
case_name = "Baseline experiment historic data, histogram bins"
df_avgsm_mses_4, perf_4, sig_4 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.20438991 0.20579696 0.20494282 0.20483128 0.204135  ] s
# Mean time per simulation step: 0.205 s, std: 0.0006 s
# Total execution time: 20481.919 s for 100000 steps -> 0.205 s per step
#
# Median performance (MSE) in exploitation mode 0.0123
#
# Average MSE in exploitation mode 0.0134 +- 0.0036
# Average exploitation performance of each agent:
# [0.014122 0.012516 0.01289  0.013914 0.013694]

# %%
experiments_folder = case_folder + "discretization/ql_ql12_32ep_hist_bins/"
experiment_name = "Stoch.PS, window Q-learning:"
case = "window_size=1"
case_name = "Q-learning experiment historic data, histogram bins"
df_avgsm_mses_4, perf_4, sig_4 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.20492727 0.20433636 0.20468202 0.20433824 0.20528785] s
# Mean time per simulation step: 0.205 s, std: 0.0004 s
# Total execution time: 20471.435 s for 100000 steps -> 0.205 s per step
#
# Median performance (MSE) in exploitation mode 0.0126
#
# Average MSE in exploitation mode 0.0136 +- 0.0034
# Average exploitation performance of each agent:
# [0.013674 0.013694 0.013592 0.014602 0.012558]

# %% [markdown]
# ### Binning using reference power level as an edge of the bin

# %%
experiments_folder = case_folder + "discretization/ql_baseline_p_ref_10bins/"
experiment_name = "Stoch.PS, window Q-learning:"
case = "window_size=1"
case_name = "Baseline experiment historic data, ref.pow.edge 10 bins"
df_avgsm_mses_4, perf_4, sig_4 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.20555215 0.20501562 0.20532863 0.20488162 0.20555357] s
# Mean time per simulation step: 0.205 s, std: 0.0003 s
# Total execution time: 20526.632 s for 100000 steps -> 0.205 s per step
#
# Median performance (MSE) in exploitation mode 0.0123
#
# Average MSE in exploitation mode 0.0131 +- 0.0030
# Average exploitation performance of each agent:
# [0.013304 0.013124 0.013134 0.012692 0.01318 ]

# %%
experiments_folder = case_folder + "discretization/ql_ql12_32ep_p_ref_10bins/"
experiment_name = "Stoch.PS, window Q-learning:"
case = "window_size=1"
case_name = "Q-learning experiment historic data, ref.pow.edge 10 bins"
df_avgsm_mses_4, perf_4, sig_4 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.22959437 0.21909439 0.20517009 0.20534731 0.20600325] s
# Mean time per simulation step: 0.213 s, std: 0.0098 s
# Total execution time: 21304.188 s for 100000 steps -> 0.213 s per step
#
# Median performance (MSE) in exploitation mode 0.0126
#
# Average MSE in exploitation mode 0.0132 +- 0.0049
# Average exploitation performance of each agent:
# [0.013508 0.013    0.013798 0.01271  0.013132]

# %%
labels = ["Hist.bas.", "Hist.q-l.", "Quant.bas.", "Quant.q-l.", "Ref.pow.bas.\n10 bins", "Ref.pow.q-l.\n10 bins",
         "100bins\n[0.1;1.7]"]
bas_folders = [baseline_name +"/k=7"]
contr_folders = ["ps_stoch_adv/discretization/ql_baseline12_hist_bins/window_size=1",
                 "ps_stoch_adv/discretization/ql_ql12_32ep_hist_bins/window_size=1",
                 "ps_stoch_adv/discretization/ql_baseline12_quantile_10bins/window_size=1",
                 "ps_stoch_adv/discretization/ql_ql12_32ep_quantile_10bins/window_size=1",
                 "ps_stoch_adv/discretization/ql_baseline_p_ref_10bins/window_size=1",
                 "ps_stoch_adv/discretization/ql_ql12_32ep_p_ref_10bins/window_size=1",
                 "ps_stoch/best_parameters_combination_19-09-2019_13-33/time_step=1"
                 ]

perf_box_plots(labels, bas_folders, contr_folders, fig_size=(15, 6), x_label="Discretization strategy")
# Out:
# ([], [])

# %%
perf_viol_split(labels, [bas_folders[0], bas_folders[0],
                        bas_folders[0],bas_folders[0],
                        bas_folders[0], bas_folders[0], bas_folders[0]],
                contr_folders, fig_size=(10, 6), x_label="Discretization strategy");

# %% [markdown]
# ## Train histogram case longer

# %%
experiments_folder = case_folder + "discretization/ql_baseline12_hist_bins_200ep/"
experiment_name = "Stoch.PS, window Q-learning:"
case = "window_size=1"
case_name = "Baseline experiment historic data, optimal histogram bins"
df_avgsm_mses_4, perf_4, sig_4 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.17923659 0.17191276 0.17238779 0.17210468 0.17286388] s
# Mean time per simulation step: 0.174 s, std: 0.0028 s
# Total execution time: 34740.228 s for 200000 steps -> 0.174 s per step
#
# Median performance (MSE) in exploitation mode 0.0122
#
# Average MSE in exploitation mode 0.0131 +- 0.0015
# Average exploitation performance of each agent:
# [0.012634 0.01303  0.012784 0.01302  0.013814]

# %%
plot_perf_dist(baseline_name +"/k=7", ["ps_stoch_adv/discretization/ql_baseline12_hist_bins/window_size=1",
                 "ps_stoch_adv/discretization/ql_baseline12_hist_bins_200ep/window_size=1"], 
               ["Histogram bins", "Histogram bins (200 ep.)"], fig_size=(10, 25));

# %%
experiments_folder = case_folder + "discretization/ql_baseline_p_ref_10bins_200ep/"
experiment_name = "Stoch.PS, window Q-learning:"
case = "window_size=1"
case_name = "Baseline experiment historic data, optimal histogram bins"
df_avgsm_mses_4, perf_4, sig_4 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.22352943 0.17021973 0.17104411 0.17053013 0.17046018] s
# Mean time per simulation step: 0.181 s, std: 0.0212 s
# Total execution time: 36231.343 s for 200000 steps -> 0.181 s per step
#
# Median performance (MSE) in exploitation mode 0.0132
#
# Average MSE in exploitation mode 0.0164 +- 0.0073
# Average exploitation performance of each agent:
# [0.013466 0.030948 0.012492 0.01244  0.012876]

# %%
experiments_folder = case_folder + "discretization/ql_baseline_p_ref_10bins_200ep_wo_disconv/"
experiment_name = "Stoch.PS, window Q-learning:"
case = "window_size=1"
case_name = "Baseline experiment historic data, optimal histogram bins"
df_avgsm_mses_4, perf_4, sig_4 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.22352943 0.17021973 0.17104411 0.17053013 0.17046018] s
# Mean time per simulation step: 0.181 s, std: 0.0212 s
# Total execution time: 36231.343 s for 200000 steps -> 0.181 s per step
#
# Median performance (MSE) in exploitation mode 0.0132
#
# Average MSE in exploitation mode 0.0164 +- 0.0073
# Average exploitation performance of each agent:
# [0.013466 0.030948 0.012492 0.01244  0.012876]

# %%
plot_agent_sys_exploit_behaviour(experiments_folder+"window_size=1")

# %%
plot_perf_dist(baseline_name +"/k=7", ["ps_stoch_adv/discretization/ql_baseline_p_ref_10bins/window_size=1",
                 "ps_stoch_adv/discretization/ql_baseline_p_ref_10bins_200ep/window_size=1"], 
               ["P_ref bins", "P_ref bins (200 ep.)"], fig_size=(10, 25));

# %%
labels = ["Hist.bas.", "Hist.bas.200ep.", "Ref.pow.bas.\n10 bins", "Ref.pow.bas.\n10 bins, 200ep.", "10 bins\n[0.9;1.7]",
         "100bins\n[0.1;1.7]"]
bas_folders = [baseline_name +"/k=7"]
contr_folders = ["ps_stoch_adv/discretization/ql_baseline12_hist_bins/window_size=1",
                 "ps_stoch_adv/discretization/ql_baseline12_hist_bins_200ep/window_size=1",
                 "ps_stoch_adv/discretization/ql_baseline_p_ref_10bins/window_size=1",
                 "ps_stoch_adv/discretization/ql_baseline_p_ref_10bins_200ep/window_size=1",
                 "ps_stoch_adv/wiql/slide_win_exp_10_09-17_bins/window_size=1",
                 "ps_stoch/exploration(rate_and_discount)_variation_25-10-2019_11-33/expl_rate=0.5_decay=0.999"
                 ]

perf_box_plots(labels, bas_folders, contr_folders, fig_size=(15, 6), x_label="Discretization strategy",
              color='lightgray');

# %%
perf_viol_split(labels, [bas_folders[0], bas_folders[0],
                        bas_folders[0],bas_folders[0],
                        bas_folders[0], bas_folders[0]], contr_folders, fig_size=(9, 6), x_label="Discretization strategy");

# %% [markdown]
# ## 2. With skipping transition process (175s)

# %%
skip_trans_baseline_name = "ps_stoch/new_compete/baseline12_skip175_50ep_1s"
report_const_experiment(skip_trans_baseline_name, fig_size=(12, 35))

# %% [markdown]
# ### Binning using quantiles

# %%
experiments_folder = case_folder + "discretization/ql_baseline12_quantile_10bins_skip_175/"
experiment_name = "Stoch.PS, window Q-learning:"
case = "window_size=1"
case_name = "Baseline experiment historic data, 10 quantile bins"
df_avgsm_mses_4, perf_4, sig_4 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.20693297 0.20693829 0.20734217 0.20762777 0.20735536] s
# Mean time per simulation step: 0.207 s, std: 0.0003 s
# Total execution time: 20723.931 s for 100000 steps -> 0.207 s per step
#
# Median performance (MSE) in exploitation mode 0.0086
#
# Average MSE in exploitation mode 0.0087 +- 0.0029
# Average exploitation performance of each agent:
# [0.00861  0.008932 0.009178 0.008222 0.008784]

# %%
experiments_folder = case_folder + "discretization/ql_ql12_32ep_quantile_10bins_skip_175/"
experiment_name = "Stoch.PS, window Q-learning:"
case = "window_size=1"
case_name = "Q-learning experiment historic data, 10 quantile bins"
df_avgsm_mses_4, perf_4, sig_4 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.21241013 0.21007741 0.21024208 0.21041063 0.21025945] s
# Mean time per simulation step: 0.211 s, std: 0.0009 s
# Total execution time: 21067.994 s for 100000 steps -> 0.211 s per step
#
# Median performance (MSE) in exploitation mode 0.0084
#
# Average MSE in exploitation mode 0.0086 +- 0.0028
# Average exploitation performance of each agent:
# [0.008988 0.008098 0.00828  0.0085   0.009108]

# %% [markdown]
# ### Binning using histogram

# %%
experiments_folder = case_folder + "discretization/ql_baseline12_hist_bins_skip_175/"
experiment_name = "Stoch.PS, window Q-learning:"
case = "window_size=1"
case_name = "Baseline experiment historic data, histogram bins"
df_avgsm_mses_4, perf_4, sig_4 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.20643969 0.20642009 0.20656626 0.2090171  0.20888814] s
# Mean time per simulation step: 0.207 s, std: 0.0012 s
# Total execution time: 20746.625 s for 100000 steps -> 0.207 s per step
#
# Median performance (MSE) in exploitation mode 0.0084
#
# Average MSE in exploitation mode 0.0087 +- 0.0034
# Average exploitation performance of each agent:
# [0.009184 0.00919  0.007918 0.008414 0.00885 ]

# %%
experiments_folder = case_folder + "discretization/ql_ql12_32ep_hist_bins_skip_175/"
experiment_name = "Stoch.PS, window Q-learning:"
case = "window_size=1"
case_name = "Q-learning experiment historic data, histogram bins"
df_avgsm_mses_4, perf_4, sig_4 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.20940864 0.20956851 0.22069043 0.21049458 0.23552045] s
# Mean time per simulation step: 0.217 s, std: 0.0101 s
# Total execution time: 21713.652 s for 100000 steps -> 0.217 s per step
#
# Median performance (MSE) in exploitation mode 0.0083
#
# Average MSE in exploitation mode 0.0083 +- 0.0029
# Average exploitation performance of each agent:
# [0.008272 0.008234 0.008678 0.008338 0.008184]

# %% [markdown]
# ### Binning using reference power level as an edge of the bin

# %%
experiments_folder = case_folder + "discretization/ql_baseline_p_ref_10bins_skip175/"
experiment_name = "Stoch.PS, window Q-learning:"
case = "window_size=1"
case_name = "Baseline experiment historic data, ref.pow.edge 10 bins"
df_avgsm_mses_4, perf_4, sig_4 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.21129038 0.21102435 0.21199028 0.2121704  0.21366214] s
# Mean time per simulation step: 0.212 s, std: 0.0009 s
# Total execution time: 21202.751 s for 100000 steps -> 0.212 s per step
#
# Median performance (MSE) in exploitation mode 0.0086
#
# Average MSE in exploitation mode 0.0087 +- 0.0026
# Average exploitation performance of each agent:
# [0.009218 0.008122 0.008664 0.008834 0.008866]

# %%
experiments_folder = case_folder + "discretization/ql_ql12_32ep_p_ref_10bins_skip175/"
experiment_name = "Stoch.PS, window Q-learning:"
case = "window_size=1"
case_name = "Q-learning experiment historic data, ref.pow.edge 10 bins"
df_avgsm_mses_4, perf_4, sig_4 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.21212573 0.21177706 0.21169289 0.21177868 0.21184529] s
# Mean time per simulation step: 0.212 s, std: 0.0001 s
# Total execution time: 21184.393 s for 100000 steps -> 0.212 s per step
#
# Median performance (MSE) in exploitation mode 0.0087
#
# Average MSE in exploitation mode 0.0091 +- 0.0019
# Average exploitation performance of each agent:
# [0.009444 0.009486 0.008998 0.008938 0.008778]

# %%
experiments_folder = case_folder + "discretization/ql_25bins_09-17_skip175/"
experiment_name = "Stoch.PS, window Q-learning:"
case = "window_size=1"
case_name = "Q-learning experiment historic data, 25 bins in [0.9;1.7]"
df_avgsm_mses_4, perf_4, sig_4 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.21381604 0.20786022 0.20781087 0.20741161 0.20724702] s
# Mean time per simulation step: 0.209 s, std: 0.0025 s
# Total execution time: 20882.915 s for 100000 steps -> 0.209 s per step
#
# Median performance (MSE) in exploitation mode 0.0085
#
# Average MSE in exploitation mode 0.0086 +- 0.0018
# Average exploitation performance of each agent:
# [0.00831  0.008932 0.0086   0.008704 0.00856 ]

# %%
labels = ["Hist.bas.", "Hist.q-l.", "Quant.bas.", "Quant.q-l.", "Ref.pow.\nbas.10 bins", "Ref.pow.\nq-l.10 bins",
         "25 bins\n[0.9;1.7]", "100 bins\n[0.1;1.7]"]
bas_folders = [skip_trans_baseline_name +"/k=7"]
contr_folders = ["ps_stoch_adv/discretization/ql_baseline12_hist_bins_skip_175/window_size=1",
                 "ps_stoch_adv/discretization/ql_ql12_32ep_hist_bins_skip_175/window_size=1",
                 "ps_stoch_adv/discretization/ql_baseline12_quantile_10bins_skip_175/window_size=1",
                 "ps_stoch_adv/discretization/ql_ql12_32ep_quantile_10bins_skip_175/window_size=1",
                 "ps_stoch_adv/discretization/ql_baseline_p_ref_10bins_skip175/window_size=1",
                 "ps_stoch_adv/discretization/ql_ql12_32ep_p_ref_10bins_skip175/window_size=1",
                 "ps_stoch_adv/discretization/ql_25bins_09-17_skip175/window_size=1",
                 "ps_stoch/skip_transition_experiment/best_params_skip_transition175/p_reff=1.2/time_step=1",
                 ]

perf_box_plots(labels, bas_folders, contr_folders, fig_size=(15, 6), x_label="Discretization strategy");

# %%
perf_viol_split(labels, [bas_folders[0], bas_folders[0],
                        bas_folders[0],bas_folders[0],
                        bas_folders[0],bas_folders[0],
                         bas_folders[0],bas_folders[0],
                         bas_folders[0],bas_folders[0]
                        ], contr_folders, fig_size=(12, 6), x_label="Discretization strategy");

# %% [markdown]
# ## Now, let's use historic data for binning also from experiments with skipping 175 s

# %%
experiments_folder = case_folder + "discretization/ql_baseline12_skip175_hist_bins_skip175/"
experiment_name = "Stoch.PS, window Q-learning:"
case = "window_size=1"
case_name = "Baseline experiment historic data, optimal histogram bins"
df_avgsm_mses_4, perf_4, sig_4 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.20975858 0.21017532 0.21022624 0.21053708 0.2111168 ] s
# Mean time per simulation step: 0.210 s, std: 0.0005 s
# Total execution time: 21036.280 s for 100000 steps -> 0.210 s per step
#
# Median performance (MSE) in exploitation mode 0.0086
#
# Average MSE in exploitation mode 0.0088 +- 0.0033
# Average exploitation performance of each agent:
# [0.008838 0.009398 0.008744 0.008172 0.00892 ]

# %%
experiments_folder = case_folder + "discretization/ql_baseline12_skip175_p_ref_10bins_skip175/"
experiment_name = "Stoch.PS, window Q-learning:"
case = "window_size=1"
case_name = "Baseline experiment historic data, ref.pow edge bins"
df_avgsm_mses_4, perf_4, sig_4 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.2365556  0.20987538 0.21054929 0.21142503 0.21308056] s
# Mean time per simulation step: 0.216 s, std: 0.0102 s
# Total execution time: 21629.717 s for 100000 steps -> 0.216 s per step
#
# Median performance (MSE) in exploitation mode 0.0083
#
# Average MSE in exploitation mode 0.0085 +- 0.0025
# Average exploitation performance of each agent:
# [0.008214 0.00895  0.008098 0.008512 0.00859 ]

# %%
perf_viol_split([labels[1], "Hist.baseline, skip 175s,\nopt.hist.", "Hist.baseline, skip 175s,\np.ref.10bins",
                labels[-1]], 
                [bas_folders[0], bas_folders[0],  bas_folders[0], bas_folders[0]], 
                [contr_folders[1],
                "ps_stoch_adv/discretization/ql_baseline12_skip175_hist_bins_skip175/window_size=1",
                "ps_stoch_adv/discretization/ql_baseline12_skip175_p_ref_10bins_skip175/window_size=1",
                                                                    contr_folders[-1]], 
                fig_size=(9, 6), x_label="Discretization strategy");

# %%
labels = ["Hist.bas.","Hist.bas.175s", "Hist.q-l.", "Quant.bas.", "Quant.q-l.", "Ref.pow.\nbas.10 bins", 
          "Ref.pow.\nq-l.10 bins", "Ref.pow.(175s)\nq-l.10 bins",
         "25 bins\n[0.9;1.7]", "100 bins\n[0.1;1.7]"]
bas_folders = [skip_trans_baseline_name +"/k=5"]
contr_folders = ["ps_stoch_adv/discretization/ql_baseline12_hist_bins_skip_175/window_size=1",
                 "ps_stoch_adv/discretization/ql_baseline12_skip175_hist_bins_skip175/window_size=1",
                 "ps_stoch_adv/discretization/ql_ql12_32ep_hist_bins_skip_175/window_size=1",
                 "ps_stoch_adv/discretization/ql_baseline12_quantile_10bins_skip_175/window_size=1",
                 "ps_stoch_adv/discretization/ql_ql12_32ep_quantile_10bins_skip_175/window_size=1",
                 "ps_stoch_adv/discretization/ql_baseline_p_ref_10bins_skip175/window_size=1",
                 "ps_stoch_adv/discretization/ql_ql12_32ep_p_ref_10bins_skip175/window_size=1",
                 "ps_stoch_adv/discretization/ql_baseline12_skip175_p_ref_10bins_skip175/window_size=1",
                 "ps_stoch_adv/discretization/ql_25bins_09-17_skip175/window_size=1",
                 "ps_stoch/skip_transition_experiment/best_params_skip_transition175/p_reff=1.2/time_step=1",
                 ]

perf_box_plots(labels, bas_folders, contr_folders, fig_size=(15, 6), x_label="Discretization strategy");
