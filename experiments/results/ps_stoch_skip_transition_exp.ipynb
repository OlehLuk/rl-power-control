# %%
from visualize import report_const_experiment, report_experiment, report_experiment_summary, plot_sys_behaviour, \
plot_agent_behaviour, plot_two_perf_dist, plot_agent_sys_exploit_behaviour, mse_vs_ref
# %matplotlib inline

# %%
case_folder = "ps_stoch/skip_transition_experiment/"

# %% [markdown]
# ## Reference power level 1.2

# %%
name = "ps_stoch/new_compete/baseline12_skip175_50ep_1s/"
report_const_experiment(name, fig_size=(12, 35))

# %%
experiments_folder = case_folder + "best_params_skip_transition175/p_reff=1.2/"
experiment_name = "Stoch.PS, Q-learning:"
case = "time_step=1"
case_name = "Reference power level 1.2"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.22190393 0.22205122 0.21232548 0.2124961  0.21366175] s
# Mean time per simulation step: 0.216 s, std: 0.0045 s
# Total execution time: 21648.770 s for 100000 steps -> 0.216 s per step
#
# Median performance (MSE) in exploitation mode 0.0085
#
# Average MSE in exploitation mode 0.0087 +- 0.0036
# Average exploitation performance of each agent:
# [0.008958 0.008772 0.008244 0.009068 0.00865 ]

# %%
controller = case_folder + "best_params_skip_transition175/p_reff=1.2/time_step=1"
baseline = name + "/k=2"
plot_two_perf_dist(baseline, controller);

# %% [markdown]
# ## Reference power level 1.15

# %%
name = "ps_stoch/new_compete/baseline115_skip175_50ep_1s/"
report_const_experiment(name, fig_size=(12, 35))

# %%
experiments_folder = case_folder + "best_params_skip_transition175/p_reff=1.15/"
experiment_name = "Stoch.PS, Q-learning:"
case = "time_step=1"
case_name = "Reference power level 1.15"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.21001371 0.21036237 0.21049599 0.21136709 0.21098864] s
# Mean time per simulation step: 0.211 s, std: 0.0005 s
# Total execution time: 21064.556 s for 100000 steps -> 0.211 s per step
#
# Average MSE in exploitation mode 0.0177 +- 0.0047
# Average exploitation performance of each agent:
# [0.018246 0.017078 0.018074 0.017372 0.017638]

# %%
controller = case_folder + "best_params_skip_transition175/p_reff=1.15/time_step=1"
baseline = name + "/k=6"
plot_two_perf_dist(baseline, controller);

# %% [markdown]
# ## Reference power level 1.25

# %%
name = "ps_stoch/new_compete/baseline125_skip175_50ep_1s/"
report_const_experiment(name, fig_size=(12, 35))

# %%
experiments_folder = case_folder + "best_params_skip_transition175/p_reff=1.25/"
experiment_name = "Stoch.PS, Q-learning:"
case = "time_step=1"
case_name = "Reference power level 1.25"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.00
# Time per simulation step in each experiment: [0.21320805 0.21239201 0.21328808 0.21236599 0.21380002] s
# Mean time per simulation step: 0.213 s, std: 0.0006 s
# Total execution time: 21301.083 s for 100000 steps -> 0.213 s per step
#
# Average MSE in exploitation mode 0.0044 +- 0.0024
# Average exploitation performance of each agent:
# [0.0046   0.00436  0.004374 0.004418 0.004286]

# %%
controller = case_folder + "best_params_skip_transition175/p_reff=1.25/time_step=1"
baseline = name + "/k=7"
plot_two_perf_dist(baseline, controller);

# %% [markdown]
# ## Reference power level 1.05

# %%
name = "ps_stoch/new_compete/baseline105_skip175_50ep_1s/"
report_const_experiment(name, fig_size=(12, 35))

# %%
experiments_folder = case_folder + "best_params_skip_transition175/p_reff=1.05/"
experiment_name = "Stoch.PS, Q-learning:"
case = "time_step=1"
case_name = "Reference power level 1.05"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.05
# Time per simulation step in each experiment: [0.21298317 0.22192927 0.21561316 0.21133325 0.21167896] s
# Mean time per simulation step: 0.215 s, std: 0.0039 s
# Total execution time: 21470.756 s for 100000 steps -> 0.215 s per step
#
# Average MSE in exploitation mode 0.0502 +- 0.0139
# Average exploitation performance of each agent:
# [0.051036 0.050706 0.051528 0.047932 0.04968 ]

# %%
controller = case_folder + "best_params_skip_transition175/p_reff=1.05/time_step=1"
baseline = name + "/k=7"
plot_two_perf_dist(baseline, controller);

# %% [markdown]
# ## Reference power level 1.35

# %%
name = "ps_stoch/new_compete/baseline135_skip175_50ep_1s/"
report_const_experiment(name, fig_size=(12, 35))

# %%
experiments_folder = case_folder + "best_params_skip_transition175/p_reff=1.35/"
experiment_name = "Stoch.PS, Q-learning:"
case = "time_step=1"
case_name = "Reference power level 1.35"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.21222913 0.21286095 0.21334354 0.21308497 0.21312798] s
# Mean time per simulation step: 0.213 s, std: 0.0004 s
# Total execution time: 21292.931 s for 100000 steps -> 0.213 s per step
#
# Average MSE in exploitation mode 0.0086 +- 0.0024
# Average exploitation performance of each agent:
# [0.008686 0.010476 0.007786 0.00815  0.007666]

# %%
controller = case_folder + "best_params_skip_transition175/p_reff=1.35/time_step=1"
baseline = name + "/k=7"
plot_two_perf_dist(baseline, controller);

# %% [markdown]
# ## Summary

# %%
labels = ["1.05", "1.15", "1.2", "1.25", "1.35"]
bas_folders = ["ps_stoch/new_compete/baseline105_skip175_50ep_1s/k=7",
               "ps_stoch/new_compete/baseline115_skip175_50ep_1s/k=6",
               "ps_stoch/new_compete/baseline12_skip175_50ep_1s/k=2",
               "ps_stoch/new_compete/baseline125_skip175_50ep_1s/k=7",
               "ps_stoch/new_compete/baseline135_skip175_50ep_1s/k=7"
               ]
contr_folders = ["ps_stoch/skip_transition_experiment/best_params_skip_transition175/p_reff=1.05/time_step=1",
                 "ps_stoch/skip_transition_experiment/best_params_skip_transition175/p_reff=1.15/time_step=1",
                 "ps_stoch/skip_transition_experiment/best_params_skip_transition175/p_reff=1.2/time_step=1",
                 "ps_stoch/skip_transition_experiment/best_params_skip_transition175/p_reff=1.25/time_step=1",
                 "ps_stoch/skip_transition_experiment/best_params_skip_transition175/p_reff=1.35/time_step=1",
                 ]

# %%
df_bas_mses, df_contr_mses = mse_vs_ref(labels, bas_folders, contr_folders, fig_size=(10, 6))
