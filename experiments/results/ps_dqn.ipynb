# %%
from visualize import report_const_experiment, report_experiment, report_experiment_summary, plot_sys_behaviour, \
plot_agent_behaviour, plot_two_perf_dist, plot_agent_sys_exploit_behaviour, mse_vs_ref, perf_viol_split
# %matplotlib inline

# %%
case_folder = "ps_stoch_adv/dqn/"

# %%
name = "ps_stoch/new_compete/baseline12_50ep_1s/"
report_const_experiment(name, fig_size=(12, 35))

# %%
experiments_folder = case_folder + "dqn_24-12-2019_17-58/"
experiment_name = "Stoch.PS, DQN:"
case = "window_size=4"
case_name = "Reference power level 1.2, DQN"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.21625446 0.22034393 0.22254502 0.22366391 0.22394591] s
# Mean time per simulation step: 0.221 s, std: 0.0028 s
# Total execution time: 22135.065 s for 100000 steps -> 0.221 s per step
#
# Median performance (MSE) in exploitation mode 0.0152
#
# Average MSE in exploitation mode 0.0164 +- 0.0054
# Average exploitation performance of each agent:
# [0.016368 0.016852 0.015862 0.016286 0.016794]

# %%
experiments_folder = case_folder + "dqn_expl_fin_001_25-12-2019_11-09/"
experiment_name = "Stoch.PS, DQN:"
case = "window_size=4"
case_name = "Reference power level 1.2, DQN"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.44736466 0.21516585 0.21536226 0.21604111 0.21568328] s
# Mean time per simulation step: 0.262 s, std: 0.0927 s
# Total execution time: 26192.344 s for 100000 steps -> 0.262 s per step
#
# Median performance (MSE) in exploitation mode 0.0159
#
# Average MSE in exploitation mode 0.0167 +- 0.0048
# Average exploitation performance of each agent:
# [0.01639  0.015834 0.017518 0.016746 0.01678 ]

# %%
experiments_folder = case_folder + "dqn_expl_expl_step_decay_26-12-2019_13-40/"
experiment_name = "Stoch.PS, DQN:"
case = "window_size=4"
case_name = "Reference power level 1.2, DQN"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.21635294 0.21741748 0.21586471 0.21707665 0.22152997] s
# Mean time per simulation step: 0.218 s, std: 0.0020 s
# Total execution time: 21764.835 s for 100000 steps -> 0.218 s per step
#
# Median performance (MSE) in exploitation mode 0.0164
#
# Average MSE in exploitation mode 0.0171 +- 0.0032
# Average exploitation performance of each agent:
# [0.017434 0.017396 0.017286 0.01659  0.016992]

# %%
experiments_folder = case_folder + "dqn_expl_buffer_size_26-12-2019_07-34/"
experiment_name = "Stoch.PS, DQN:"
case = "window_size=4"
case_name = "Reference power level 1.2, DQN"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.22074669 0.22059423 0.2194719  0.21742795 0.21705239] s
# Mean time per simulation step: 0.219 s, std: 0.0016 s
# Total execution time: 21905.863 s for 100000 steps -> 0.219 s per step
#
# Median performance (MSE) in exploitation mode 0.0161
#
# Average MSE in exploitation mode 0.0169 +- 0.0053
# Average exploitation performance of each agent:
# [0.01651  0.01668  0.016746 0.01761  0.017144]

# %%
experiments_folder = case_folder + "dqn_expl_winsize_25-12-2019_18-56/"
experiment_name = "Stoch.PS, DQN:"
case = "window_size=2"
case_name = "Reference power level 1.2, DQN"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.22458834 0.22452631 0.22492007 0.22457473 0.22570064] s
# Mean time per simulation step: 0.225 s, std: 0.0004 s
# Total execution time: 22486.202 s for 100000 steps -> 0.225 s per step
#
# Median performance (MSE) in exploitation mode 0.0144
#
# Average MSE in exploitation mode 0.0154 +- 0.0023
# Average exploitation performance of each agent:
# [0.014228 0.01562  0.016822 0.015016 0.015538]

# %%
experiments_folder = case_folder + "dqn_expl_winsize_25-12-2019_18-56/"
experiment_name = "Stoch.PS, DQN:"
case = "window_size=1"
case_name = "Reference power level 1.2, DQN"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.23325152 0.22554914 0.22758614 0.23345528 0.23193664] s
# Mean time per simulation step: 0.230 s, std: 0.0032 s
# Total execution time: 23035.575 s for 100000 steps -> 0.230 s per step
#
# Median performance (MSE) in exploitation mode 0.0132
#
# Average MSE in exploitation mode 0.0144 +- 0.0039
# Average exploitation performance of each agent:
# [0.015168 0.014172 0.013458 0.015814 0.013408]

# %%
plot_two_perf_dist(name+"/k=7", experiments_folder+case)

# %% [markdown]
# ## Batch size 32

# %%
experiments_folder = case_folder + "dqn_expl_big_batch_27-12-2019_16-10/"
experiment_name = "Stoch.PS, DQN:"
case = "window_size=4"
case_name = "Reference power level 1.2, DQN"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.21607602 0.2155504  0.21608774 0.21932501 0.24232766] s
# Mean time per simulation step: 0.222 s, std: 0.0103 s
# Total execution time: 22187.337 s for 100000 steps -> 0.222 s per step
#
# Median performance (MSE) in exploitation mode 0.0158
#
# Average MSE in exploitation mode 0.0164 +- 0.0018
# Average exploitation performance of each agent:
# [0.01704  0.01559  0.01601  0.016962 0.016348]

# %% [markdown]
# ## Buffer size 500

# %%
experiments_folder = case_folder + "dqn_expl_big_buffer_26-12-2019_20-40/"
experiment_name = "Stoch.PS, DQN:"
case = "window_size=4"
case_name = "Reference power level 1.2, DQN"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.22897449 0.22884749 0.24191576 0.23651056 0.24621917] s
# Mean time per simulation step: 0.236 s, std: 0.0069 s
# Total execution time: 23649.349 s for 100000 steps -> 0.236 s per step
#
# Median performance (MSE) in exploitation mode 0.0163
#
# Average MSE in exploitation mode 0.0171 +- 0.0047
# Average exploitation performance of each agent:
# [0.017524 0.016628 0.017338 0.017328 0.016808]

# %% [markdown]
# ## Discount factor 0.9

# %%
experiments_folder = case_folder + "dqn_expl_high_discount_27-12-2019_10-10/"
experiment_name = "Stoch.PS, DQN:"
case = "window_size=4"
case_name = "Reference power level 1.2, DQN"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.21621934 0.21653745 0.21651305 0.21645687 0.21618009] s
# Mean time per simulation step: 0.216 s, std: 0.0002 s
# Total execution time: 21638.136 s for 100000 steps -> 0.216 s per step
#
# Median performance (MSE) in exploitation mode 0.0158
#
# Average MSE in exploitation mode 0.0168 +- 0.0020
# Average exploitation performance of each agent:
# [0.015482 0.017482 0.01704  0.01675  0.017094]

# %% [markdown]
# ## Hidden layers 32-32

# %%
experiments_folder = case_folder + "dqn_expl_wide_hidden_27-12-2019_03-14/"
experiment_name = "Stoch.PS, DQN:"
case = "window_size=4"
case_name = "Reference power level 1.2, DQN"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.24698164 0.24560754 0.24863715 0.25972337 0.24614136] s
# Mean time per simulation step: 0.249 s, std: 0.0053 s
# Total execution time: 24941.821 s for 100000 steps -> 0.249 s per step
#
# Median performance (MSE) in exploitation mode 0.0151
#
# Average MSE in exploitation mode 0.0164 +- 0.0039
# Average exploitation performance of each agent:
# [0.016962 0.016596 0.01653  0.015552 0.016156]

# %%
plot_two_perf_dist(name+"/k=7", experiments_folder+case)

# %% [markdown]
# ## Target net update every 25 steps

# %%
experiments_folder = case_folder + "dqn_targetupdate_low_27-12-2019_22-54/"
experiment_name = "Stoch.PS, DQN:"
case = "window_size=4"
case_name = "Reference power level 1.2, DQN"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.27505454 0.22220134 0.22032825 0.22053196 0.22066669] s
# Mean time per simulation step: 0.232 s, std: 0.0217 s
# Total execution time: 23175.655 s for 100000 steps -> 0.232 s per step
#
# Median performance (MSE) in exploitation mode 0.0156
#
# Average MSE in exploitation mode 0.0165 +- 0.0050
# Average exploitation performance of each agent:
# [0.015486 0.015782 0.016142 0.017272 0.018066]

# %% [markdown]
# ## Target net update every 400 steps

# %%
experiments_folder = case_folder + "dqn_targetupdate_high_28-12-2019_05-21/"
experiment_name = "Stoch.PS, DQN:"
case = "window_size=4"
case_name = "Reference power level 1.2, DQN"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.22026658 0.21975461 0.21995884 0.22042824 0.22056449] s
# Mean time per simulation step: 0.220 s, std: 0.0003 s
# Total execution time: 22019.455 s for 100000 steps -> 0.220 s per step
#
# Median performance (MSE) in exploitation mode 0.0162
#
# Average MSE in exploitation mode 0.0174 +- 0.0043
# Average exploitation performance of each agent:
# [0.018624 0.017422 0.017192 0.018096 0.015814]

# %% [markdown]
# ## Trying find best combination for win.size 1
# hidden layers 64-64
# batch size 16, buffer size 200
# target update 25

# %%
experiments_folder = case_folder + "dqn_best_28-12-2019_13-10/"
experiment_name = "Stoch.PS, DQN:"
case = "window_size=1"
case_name = "Reference power level 1.2, DQN"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.26856803 0.25844809 0.2670376  0.23342897 0.22911958] s
# Mean time per simulation step: 0.251 s, std: 0.0168 s
# Total execution time: 25132.045 s for 100000 steps -> 0.251 s per step
#
# Median performance (MSE) in exploitation mode 0.0135
#
# Average MSE in exploitation mode 0.0145 +- 0.0023
# Average exploitation performance of each agent:
# [0.014086 0.014618 0.01394  0.014436 0.015266]

# %% [markdown]
# ## Trying find best combination for win.size 1
# hidden layers 64-64
# batch size 16, buffer size 200
# target update 25
# exploratio rate final=0.01
# 200 episodes

# %%
experiments_folder = case_folder + "dqn_best_long_28-12-2019_20-36/"
experiment_name = "Stoch.PS, DQN:"
case = "window_size=1"
case_name = "Reference power level 1.2, DQN"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.20512653 0.19576784 0.19525944 0.19569416 0.19461369] s
# Mean time per simulation step: 0.197 s, std: 0.0039 s
# Total execution time: 39458.466 s for 200000 steps -> 0.197 s per step
#
# Median performance (MSE) in exploitation mode 0.0136
#
# Average MSE in exploitation mode 0.0142 +- 0.0045
# Average exploitation performance of each agent:
# [0.014268 0.013898 0.0142   0.01362  0.014986]

# %%
experiments_folder = case_folder + "dqn_best_2_29-12-2019_09-56/"
experiment_name = "Stoch.PS, DQN:"
case = "window_size=1"
case_name = "Reference power level 1.2, DQN"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.22651721 0.22527431 0.22659881 0.25655829 0.24001962] s
# Mean time per simulation step: 0.235 s, std: 0.0121 s
# Total execution time: 23499.365 s for 100000 steps -> 0.235 s per step
#
# Median performance (MSE) in exploitation mode 0.0135
#
# Average MSE in exploitation mode 0.0144 +- 0.0021
# Average exploitation performance of each agent:
# [0.014576 0.013684 0.014532 0.014896 0.014512]

# %% [markdown]
# ## DQN best 3

# %%
experiments_folder = case_folder + "dqn_best_3_31-12-2019_15-33/"
experiment_name = "Stoch.PS, DQN:"
case = "window_size=1"
case_name = "Reference power level 1.2, DQN"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.21644185 0.21486706 0.21515248 0.21682696 0.21577811] s
# Mean time per simulation step: 0.216 s, std: 0.0007 s
# Total execution time: 21581.329 s for 100000 steps -> 0.216 s per step
#
# Median performance (MSE) in exploitation mode 0.0140
#
# Average MSE in exploitation mode 0.0153 +- 0.0050
# Average exploitation performance of each agent:
# [0.015322 0.015076 0.014594 0.01522  0.01612 ]

# %% [markdown]
# ## DQN as q.-l.

# %%
experiments_folder = case_folder + "dqn_as_ql_01-01-2020_03-33/"
experiment_name = "Stoch.PS, DQN:"
case = "window_size=1"
case_name = "Reference power level 1.2, DQN"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.21520754 0.21561724 0.2158234  0.21536312 0.21570749] s
# Mean time per simulation step: 0.216 s, std: 0.0002 s
# Total execution time: 21554.376 s for 100000 steps -> 0.216 s per step
#
# Median performance (MSE) in exploitation mode 0.0133
#
# Average MSE in exploitation mode 0.0141 +- 0.0036
# Average exploitation performance of each agent:
# [0.01356  0.014202 0.01446  0.013464 0.014876]

# %% [markdown]
# ## Skip 175s

# %%
experiments_folder = case_folder + "dqn_skip175_25-12-2019_00-07/"
experiment_name = "Stoch.PS, DQN:"
case = "window_size=4"
case_name = "Reference power level 1.2, DQN"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.22924246 0.22900671 0.22922049 0.22822688 0.22834828] s
# Mean time per simulation step: 0.229 s, std: 0.0004 s
# Total execution time: 22880.896 s for 100000 steps -> 0.229 s per step
#
# Median performance (MSE) in exploitation mode 0.0088
#
# Average MSE in exploitation mode 0.0089 +- 0.0029
# Average exploitation performance of each agent:
# [0.008932 0.009254 0.00862  0.00908  0.008772]

# %%
plot_two_perf_dist("ps_stoch/new_compete/baseline12_skip175_50ep_1s/k=2", experiments_folder+case)

# %%
experiments_folder = case_folder + "dqn_skip175_best_29-12-2019_16-27/"
experiment_name = "Stoch.PS, DQN:"
case = "window_size=2"
case_name = "Reference power level 1.2, DQN"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.2443092  0.23347157 0.24373918 0.25765478 0.23755874] s
# Mean time per simulation step: 0.243 s, std: 0.0082 s
# Total execution time: 24334.669 s for 100000 steps -> 0.243 s per step
#
# Median performance (MSE) in exploitation mode 0.0092
#
# Average MSE in exploitation mode 0.0091 +- 0.0024
# Average exploitation performance of each agent:
# [0.00849  0.008644 0.008898 0.010066 0.009204]

# %%
experiments_folder = case_folder + "dqn_skip175_best_2_29-12-2019_23-43/"
experiment_name = "Stoch.PS, DQN:"
case = "window_size=4"
case_name = "Reference power level 1.2, DQN"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.2477202  0.21842493 0.21825781 0.21885752 0.2189274 ] s
# Mean time per simulation step: 0.224 s, std: 0.0116 s
# Total execution time: 22443.757 s for 100000 steps -> 0.224 s per step
#
# Median performance (MSE) in exploitation mode 0.0088
#
# Average MSE in exploitation mode 0.0089 +- 0.0016
# Average exploitation performance of each agent:
# [0.00877  0.00939  0.008296 0.009104 0.00897 ]

# %% [markdown]
# ## 400 s testing

# %%
skip175test400baseline = "ps_stoch/baseline_skip_transition_long_test_19-11-2019_22-19"
report_const_experiment(skip175test400baseline, fig_size=(12, 35))

# %%
experiments_folder = case_folder + "dqn_skip175_best_long_30-12-2019_05-57/"
experiment_name = "Stoch.PS, DQN:"
case = "window_size=4"
case_name = "Reference power level 1.2, DQN"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.28901709 0.28940445 0.28968763 0.30481103 0.29552986] s
# Mean time per simulation step: 0.294 s, std: 0.0061 s
# Total execution time: 29369.001 s for 100000 steps -> 0.294 s per step
#
# Median performance (MSE) in exploitation mode 0.0088
#
# Average MSE in exploitation mode 0.0095 +- 0.0007
# Average exploitation performance of each agent:
# [0.009748 0.008554 0.01018  0.008934 0.00988 ]

# %%
plot_two_perf_dist(skip175test400baseline+"/k=2", experiments_folder+case)

# %% [markdown]
# ## DQN summary

# %%
labels = ["Best DQN", "Best DQN, skip 175s", "Best DQN, skip 175s, 400s test"]
bas_folders = [name+"/k=7", 
               "ps_stoch/new_compete/baseline12_skip175_50ep_1s/k=2",
              skip175test400baseline+"/k=2"]
contr_folders = [case_folder + "dqn_expl_winsize_25-12-2019_18-56/window_size=1",
                case_folder + "dqn_skip175_25-12-2019_00-07/window_size=4",
                 case_folder + "dqn_skip175_best_long_30-12-2019_05-57/window_size=4"]
perf_viol_split(labels, bas_folders, contr_folders, fig_size=(10, 6), x_label="");

# %% [markdown]
# ## DQN best 3

# %%
experiments_folder = case_folder + "dqn_skip175_best_3_31-12-2019_21-33/"
experiment_name = "Stoch.PS, DQN:"
case = "window_size=4"
case_name = "Reference power level 1.2, DQN"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.21619756 0.21694872 0.2160985  0.21612481 0.21673633] s
# Mean time per simulation step: 0.216 s, std: 0.0004 s
# Total execution time: 21642.118 s for 100000 steps -> 0.216 s per step
#
# Median performance (MSE) in exploitation mode 0.0089
#
# Average MSE in exploitation mode 0.0090 +- 0.0037
# Average exploitation performance of each agent:
# [0.008796 0.008824 0.009086 0.009028 0.009228]

# %% [markdown]
# ## DQN as q.-l.

# %%
experiments_folder = case_folder + "dqn_skip175_as_ql_01-01-2020_09-33/"
experiment_name = "Stoch.PS, DQN:"
case = "window_size=4"
case_name = "Reference power level 1.2, DQN"
df_avgsm_mses_1, perf_1, sig_1 = report_experiment(experiments_folder + case,
                             exp_name="\n {} {}".format(experiment_name, case_name), plot_perf_sigma=0,
                                                         stochastic=False)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.21681636 0.21766767 0.21708285 0.23816611 0.23920424] s
# Mean time per simulation step: 0.226 s, std: 0.0105 s
# Total execution time: 22578.745 s for 100000 steps -> 0.226 s per step
#
# Median performance (MSE) in exploitation mode 0.0085
#
# Average MSE in exploitation mode 0.0087 +- 0.0046
# Average exploitation performance of each agent:
# [0.00914  0.008672 0.009324 0.008606 0.007808]

# %% [markdown]
# # No control experiment

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
def no_control_performance(path, p_ref, step=1):   
    df = pd.read_csv(path, header=None)
    plt.plot(df[5])
    diffs = (df - p_ref).values
    diffs = diffs[::step]
    mses = np.mean(np.power(diffs, 2), axis=0)
    print("Mean MSE {}".format(np.mean(mses)))
    print("Std MSE {}".format(np.std(mses)))
    print("Medin MSE {}".format(np.median(mses)))
    return mses

# %%
no_control_performance("ps_stoch/new_compete/uss_no_control.csv", 1.2)
# Out:
# Mean MSE 0.0612739856557214
# Std MSE 0.019555319852180852
# Medin MSE 0.05458322467661692
# array([0.05963007, 0.05411534, 0.04742521, 0.08543772, 0.05931339,
#        0.05666016, 0.06766108, 0.04777042, 0.04911415, 0.06392088,
#        0.12315923, 0.04655792, 0.04083208, 0.04636107, 0.04750509,
#        0.04808709, 0.06489944, 0.04248963, 0.04172219, 0.04912841,
#        0.04242401, 0.04171078, 0.1072427 , 0.10615288, 0.05172173,
#        0.05977842, 0.03289236, 0.06772099, 0.07694168, 0.04120866,
#        0.07592318, 0.04423278, 0.0615615 , 0.05238932, 0.04154816,
#        0.05101135, 0.0886216 , 0.06640008, 0.049311  , 0.10275789,
#        0.07730971, 0.06478532, 0.05505111, 0.07393468, 0.05187008,
#        0.05309114, 0.07753224, 0.047274  , 0.08117258, 0.07833676])

# %%
no_control_performance("ps_stoch/new_compete/uss_skip175_no_control.csv", 1.2)
# Out:
# Mean MSE 0.03491777031641791
# Std MSE 0.03477522513550413
# Medin MSE 0.022082585472636848
# array([0.08410825, 0.00627732, 0.02274732, 0.09856408, 0.00466542,
#        0.03231892, 0.09089539, 0.04161093, 0.00364977, 0.04452377,
#        0.0501412 , 0.00282527, 0.00830291, 0.00312768, 0.01641095,
#        0.00210348, 0.15294673, 0.08481007, 0.00287948, 0.02104982,
#        0.00393221, 0.04915124, 0.02806519, 0.09847563, 0.04199322,
#        0.00417756, 0.04916265, 0.00452562, 0.0032418 , 0.0934345 ,
#        0.05019256, 0.00305351, 0.04642954, 0.05075459, 0.02141785,
#        0.01657927, 0.02332361, 0.04292328, 0.04913412, 0.03144021,
#        0.01843083, 0.01924677, 0.01772615, 0.0023688 , 0.09218206,
#        0.01489604, 0.00156142, 0.08766016, 0.00368686, 0.00276251])

# %%
no_control_performance("ps_stoch/new_compete/uss_no_control.csv", 1.2, step=5)
# Out:
# Mean MSE 0.060994564995121944
# Std MSE 0.019071841907863575
# Medin MSE 0.05486267317073171
# array([0.05505848, 0.05689069, 0.04821916, 0.08042971, 0.0625132 ,
#        0.05717042, 0.06577202, 0.04816322, 0.04922618, 0.06224746,
#        0.12299014, 0.04410718, 0.04026093, 0.05185561, 0.04666668,
#        0.04795342, 0.06083484, 0.04129592, 0.04252672, 0.05230317,
#        0.03925392, 0.04028891, 0.10324143, 0.10598275, 0.05370181,
#        0.06010755, 0.03489018, 0.06512865, 0.07826182, 0.04301624,
#        0.0749051 , 0.04282043, 0.06340833, 0.0531983 , 0.04291834,
#        0.0519675 , 0.0868914 , 0.06560418, 0.04954786, 0.10352116,
#        0.07691913, 0.06491885, 0.05466686, 0.06914273, 0.04963178,
#        0.05283465, 0.07690515, 0.04907233, 0.08188428, 0.07861148])

# %%
no_control_performance("ps_stoch/new_compete/uss_skip175_no_control.csv", 1.2, step=5)
# Out:
# Mean MSE 0.0348610859707317
# Std MSE 0.034469538026808605
# Medin MSE 0.02259618341463418
# array([0.08242975, 0.00595244, 0.02321158, 0.0979406 , 0.00525312,
#        0.0337433 , 0.08980055, 0.04098822, 0.00335098, 0.04417711,
#        0.05055488, 0.00372861, 0.00942105, 0.00302929, 0.01596666,
#        0.00219011, 0.1519139 , 0.08395426, 0.00298733, 0.02171504,
#        0.00339294, 0.04880659, 0.02768721, 0.0979406 , 0.04207916,
#        0.00412023, 0.04911429, 0.00493143, 0.00314118, 0.09367477,
#        0.04989752, 0.0032251 , 0.04596736, 0.04949192, 0.02198078,
#        0.01705759, 0.0236032 , 0.04269456, 0.04905834, 0.03296006,
#        0.0184842 , 0.01992479, 0.01714151, 0.00228802, 0.09199641,
#        0.01456802, 0.00184045, 0.08714315, 0.00378455, 0.00274956])
