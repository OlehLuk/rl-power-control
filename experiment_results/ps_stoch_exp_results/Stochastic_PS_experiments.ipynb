# %%
from stochastic_report_procedures import *
# %matplotlib inline

# %% [markdown]
# ## stochastic case with p_reff=const

# %%
name = "constant_action_variation_19-09-2019_12_54"
report_const_experiment(name)

# %% [markdown]
# ## Q-learning

# %%
df_avgsm_mses_1, perf_1, sig_1 = report_experiment("best_parameters_combination_19-09-2019_13_33/time_step=1",
                                                   plot_perf_sigma=0)
# Out:
# Last episode performance: 0.01
# Time per simulation step in each experiment: [0.30100934 0.28505123 0.29600173 0.3013342  0.35525025] s
# Mean time per simulation step: 0.308 s, std: 0.024 s
# Total execution time: 30772.935 s for 100000 steps -> 0.308 s per step
#
# Average MSE in exploitation mode 0.0132 +- 0.0052
# Average exploitatio performance of each agent:
# [0.013215 0.013781 0.013896 0.013091 0.012266]

# %%
df_avgsm_mses_2, perf_2, sig_2 = report_experiment("best_parameters_combination_19-09-2019_13_33/time_step=5",
                                                   plot_perf_sigma=0)
# Out:
# Last episode performance: 0.02
# Time per simulation step in each experiment: [0.33841488 0.31405417 0.3000132  0.29917935 0.29824352] s
# Mean time per simulation step: 0.310 s, std: 0.015 s
# Total execution time: 6199.620 s for 20000 steps -> 0.310 s per step
#
# Average MSE in exploitation mode 0.0165 +- 0.0046
# Average exploitatio performance of each agent:
# [0.015009 0.015475 0.01569  0.015653 0.02047 ]

# %%
labels = ["t=1", "t=5"]
mses = [df_avgsm_mses_1, df_avgsm_mses_2]
perfs = [perf_1, perf_2]
sigs = [sig_1, sig_2]
report_experiment_summary("Different time step", mses, perfs, sigs, labels, 0)

# %%
plot_agent_behaviour("best_parameters_combination_19-09-2019_13_33/time_step=1")

# %%
plot_sys_behaviour("best_parameters_combination_19-09-2019_13_33/time_step=1")

# %% [markdown]
# ------------------------

# %% [markdown]
# ## Stochastic case with p_reff step

# %%
name = "../ampl_stoch_ps_exp_results/constant_action_variation_20-09-2019_16_20"
report_const_experiment(name)

# %% [markdown]
# ## time_step=5

# %%
df_avgsm_mses_1, perf_1, sig_1 = report_experiment("../ampl_stoch_ps_exp_results/step_once_consid_p_reff_24-09-2019_11_43/time_step=5",
                                                   plot_perf_sigma=0)
# Out:
# Last episode performance: 0.05
# Time per simulation step in each experiment: [0.2996731  0.30610535 0.30036072 0.29873755 0.31548823] s
# Mean time per simulation step: 0.304 s, std: 0.006 s
# Total execution time: 6081.460 s for 20000 steps -> 0.304 s per step
#
# Average MSE in exploitation mode 0.0470 +- 0.0091
# Average exploitatio performance of each agent:
# [0.048217 0.047551 0.046268 0.046789 0.046316]

# %%
df_avgsm_mses_2, perf_2, sig_2 = report_experiment("../ampl_stoch_ps_exp_results/step_once_consid_p_reff_24-09-2019_16_49/time_step=5",
                                                   plot_perf_sigma=0)
# Out:
# Last episode performance: 0.05
# Time per simulation step in each experiment: [2.07652563 0.2965865  0.29621202 0.2978687  0.29932263] s
# Mean time per simulation step: 0.653 s, std: 0.712 s
# Total execution time: 13066.062 s for 20000 steps -> 0.653 s per step
#
# Average MSE in exploitation mode 0.0526 +- 0.0099
# Average exploitatio performance of each agent:
# [0.047683 0.050733 0.061647 0.055551 0.047336]

# %% [markdown]
# ## time_step=5, but action space changed from [0.1, 0.5, 1, 2, 7] to [0.1, 0.5, 1, 2, 5]

# %%
df_avgsm_mses_3, perf_3, sig_3 = report_experiment("../ampl_stoch_ps_exp_results/step_once_consid_p_reff_26-09-2019_06_26/time_step=5",
                                                   plot_perf_sigma=0)
# Out:
# Last episode performance: 0.05
# Time per simulation step in each experiment: [0.29418152 0.28925975 0.2928078  0.2939533  0.29209465] s
# Mean time per simulation step: 0.292 s, std: 0.002 s
# Total execution time: 5849.188 s for 20000 steps -> 0.292 s per step
#
# Average MSE in exploitation mode 0.0495 +- 0.0122
# Average exploitatio performance of each agent:
# [0.047992 0.058515 0.042842 0.052109 0.046077]

# %% [markdown]
# ## time_step=1

# %%
df_avgsm_mses_4, perf_4, sig_4 = report_experiment("../ampl_stoch_ps_exp_results/step_once_consid_p_reff_25-09-2019_18_40/time_step=1",
                                                   plot_perf_sigma=0)
# Out:
# Last episode performance: 0.05
# Time per simulation step in each experiment: [0.30074268 0.31048489 0.28575335 0.28004536 0.28322342] s
# Mean time per simulation step: 0.292 s, std: 0.012 s
# Total execution time: 29204.994 s for 100000 steps -> 0.292 s per step
#
# Average MSE in exploitation mode 0.0484 +- 0.0147
# Average exploitatio performance of each agent:
# [0.049526 0.060327 0.035815 0.049055 0.047122]
