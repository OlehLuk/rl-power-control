# %%
from report_procedures import *
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
df_avgsm_mses, perf, sig = report_experiment("action_space(k_s)_variation_06-09-2019_17_26/k_s=[0.1, 0.5, 1, 2, 7]", 
                                             plot_perf_sigma=2)
# Out:
# Last episode performance: 0.09
# Time per simulation step in each experiment: [0.15541062 0.1568854  0.15561405 0.15582589 0.15652317] s
# Mean time per simulation step: 0.156 s, std: 0.001 s
# Total execution time: 15605.183 s for 100000 steps -> 0.156 s per step
#
# Average MSE in exploitation mode 0.0895 +- 0.0004
# Average exploitatio performance of each agent:
# [0.0902 0.0893 0.0893 0.0894 0.0891]

# %%
df_avgsm_mses, perf, sig = report_experiment("setup_validation_11-09-2019_18_03", 
                                             plot_perf_sigma=0)
# Out:
# Last episode performance: 0.09
# Time per simulation step in each experiment: [0.15456505 0.15434382 0.24197535 0.17000477 0.17486484] s
# Mean time per simulation step: 0.179 s, std: 0.032 s
# Total execution time: 17915.077 s for 100000 steps -> 0.179 s per step
#
# Average MSE in exploitation mode 0.0892 +- 0.0007
# Average exploitatio performance of each agent:
# [0.0892 0.0902 0.0886 0.0886 0.0892]
